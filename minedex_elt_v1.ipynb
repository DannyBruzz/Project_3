# %% [markdown]
# ## ELT

# %%
# Import Dependencies
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy import inspect

# %%
# Make a reference to the solar_data_by_postcode.csv file path
csv_path = "Resources/Operating_Mines.csv"

# Import the solar_data_by_postcode.csv file as a DataFrame
minedex_elt_raw_df = pd.read_csv(csv_path, encoding="utf-8")
# Check the csv imported correctly
print(minedex_elt_raw_df.shape)
minedex_elt_raw_df.head()
# Out:
# (1329, 33)
#   SITE_CODE   SHORT_TITLE                         TITLE SITE_TYPE SUB_TYPE  \
# 0  S0000012       Baneygo                       Baneygo      Mine  Openpit
# 1  S0000030  Golden Crown  Beatons Creek - Golden Crown      Mine  Openpit
# 2  S0000033   Big Bell UG          Big Bell Underground      Mine  Decline
# 3  S0000045       Aladdin              Aladdin Open Pit      Mine  Openpit
# 4  S0000046      Bluebird     Bluebird - Bluebird South      Mine  Openpit
#
#        STAGE PROJ_CODE                 PROJECT_TITLE   LONGITUDE   LATITUDE  \
# 0  Operating    J00009     Duketon / Regis Resources  122.312500 -27.963344
# 1  Operating    J04143              Beatons Creek JV  120.101598 -21.870333
# 2  Operating    J00017  Cue Gold - Central Murchison  117.655357 -27.318659
# 3  Operating    J00017  Cue Gold - Central Murchison  118.347188 -26.869470
# 4  Operating    J00017  Cue Gold - Central Murchison  118.425102 -26.716249
#
#    ...  MAP_SHEET_NO_100K  MAP_SHEET_NAME_100K  MAP_SHEET_NO_250K  \
# 0  ...             3342.0              DUKETON            SG51-14
# 1  ...             2954.0            NULLAGINE            SF51-05
# 2  ...             2443.0                  CUE            SG50-15
# 3  ...             2544.0          MEEKATHARRA            SG50-11
# 4  ...             2544.0          MEEKATHARRA            SG50-11
#
#   MAP_SHEET_NAME_250K                LGA_NAME  \
# 0             DUKETON      LAVERTON, SHIRE OF
# 1           NULLAGINE  EAST PILBARA, SHIRE OF
# 2                 CUE           CUE, SHIRE OF
# 3              BELELE   MEEKATHARRA, SHIRE OF
# 4              BELELE   MEEKATHARRA, SHIRE OF
#
#                          DEVELOPMENT_REGION DISTRICT_NO DISTRICT_NAME  \
# 0  GOLDFIELDS-ESPERANCE, Development Region        38.0  MT. MARGARET
# 1               PILBARA, Development Region        46.0     NULLAGINE
# 2              MID-WEST, Development Region        20.0           CUE
# 3              MID-WEST, Development Region        51.0   MEEKATHARRA
# 4              MID-WEST, Development Region        51.0   MEEKATHARRA
#
#                      TECTONIC_UNIT EXTRACT_DATE
# 0  Eastern Goldfields Superterrane     20221013
# 1      Northeast Pilbara Sub-basin     20221013
# 2                  Youanmi Terrane     20221013
# 3                  Youanmi Terrane     20221013
# 4                  Youanmi Terrane     20221013
#
# [5 rows x 33 columns]
