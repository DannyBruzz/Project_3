# %% [markdown]
# ## ELT

# %%
# Import Dependencies
import pandas as pd

from sqlalchemy import create_engine
from sqlalchemy import inspect

# %%
# Make a reference to the solar_data_by_postcode.csv file path
csv_path = "Resources/Operating_Mines.csv"

# Import the solar_data_by_postcode.csv file as a DataFrame
minedex_elt_raw_df = pd.read_csv(csv_path, encoding="utf-8")
# Check the csv imported correctly
print(minedex_elt_raw_df.shape)
minedex_elt_raw_df.head()
# Out:
# (1329, 33)
#   SITE_CODE   SHORT_TITLE                         TITLE SITE_TYPE SUB_TYPE  \
# 0  S0000012       Baneygo                       Baneygo      Mine  Openpit
# 1  S0000030  Golden Crown  Beatons Creek - Golden Crown      Mine  Openpit
# 2  S0000033   Big Bell UG          Big Bell Underground      Mine  Decline
# 3  S0000045       Aladdin              Aladdin Open Pit      Mine  Openpit
# 4  S0000046      Bluebird     Bluebird - Bluebird South      Mine  Openpit
#
#        STAGE PROJ_CODE                 PROJECT_TITLE   LONGITUDE   LATITUDE  \
# 0  Operating    J00009     Duketon / Regis Resources  122.312500 -27.963344
# 1  Operating    J04143              Beatons Creek JV  120.101598 -21.870333
# 2  Operating    J00017  Cue Gold - Central Murchison  117.655357 -27.318659
# 3  Operating    J00017  Cue Gold - Central Murchison  118.347188 -26.869470
# 4  Operating    J00017  Cue Gold - Central Murchison  118.425102 -26.716249
#
#    ...  MAP_SHEET_NO_100K  MAP_SHEET_NAME_100K  MAP_SHEET_NO_250K  \
# 0  ...             3342.0              DUKETON            SG51-14
# 1  ...             2954.0            NULLAGINE            SF51-05
# 2  ...             2443.0                  CUE            SG50-15
# 3  ...             2544.0          MEEKATHARRA            SG50-11
# 4  ...             2544.0          MEEKATHARRA            SG50-11
#
#   MAP_SHEET_NAME_250K                LGA_NAME  \
# 0             DUKETON      LAVERTON, SHIRE OF
# 1           NULLAGINE  EAST PILBARA, SHIRE OF
# 2                 CUE           CUE, SHIRE OF
# 3              BELELE   MEEKATHARRA, SHIRE OF
# 4              BELELE   MEEKATHARRA, SHIRE OF
#
#                          DEVELOPMENT_REGION DISTRICT_NO DISTRICT_NAME  \
# 0  GOLDFIELDS-ESPERANCE, Development Region        38.0  MT. MARGARET
# 1               PILBARA, Development Region        46.0     NULLAGINE
# 2              MID-WEST, Development Region        20.0           CUE
# 3              MID-WEST, Development Region        51.0   MEEKATHARRA
# 4              MID-WEST, Development Region        51.0   MEEKATHARRA
#
#                      TECTONIC_UNIT EXTRACT_DATE
# 0  Eastern Goldfields Superterrane     20221013
# 1      Northeast Pilbara Sub-basin     20221013
# 2                  Youanmi Terrane     20221013
# 3                  Youanmi Terrane     20221013
# 4                  Youanmi Terrane     20221013
#
# [5 rows x 33 columns]

# %%
minedex_elt_raw_df.columns
# Out:
# Index(['SITE_CODE', 'SHORT_TITLE', 'TITLE', 'SITE_TYPE', 'SUB_TYPE', 'STAGE',
#        'PROJ_CODE', 'PROJECT_TITLE', 'LONGITUDE', 'LATITUDE', 'EASTING',
#        'NORTHING', 'MGA_ZONE', 'COMMODITIES', 'COMMODITY_GROUP_NAME',
#        'TARGET_GROUP_NAME', 'MAP_LABEL_NAME', 'INCLUDE_COMMODITY_FLAG',
#        'MAP_COMMODITIES', 'ACTIVE_FLAG', 'SYMBOL', 'MAP_SERIES',
#        'CONFIDENTIALITY', 'MAP_SHEET_NO_100K', 'MAP_SHEET_NAME_100K',
#        'MAP_SHEET_NO_250K', 'MAP_SHEET_NAME_250K', 'LGA_NAME',
#        'DEVELOPMENT_REGION', 'DISTRICT_NO', 'DISTRICT_NAME', 'TECTONIC_UNIT',
#        'EXTRACT_DATE'],
#       dtype='object')

# %%
# Reorganising the columns using double brackets
mindex_filtered_columns_df = minedex_elt_raw_df[["TITLE","SUB_TYPE","STAGE","PROJECT_TITLE","LONGITUDE", "LATITUDE","COMMODITIES","COMMODITY_GROUP_NAME","TARGET_GROUP_NAME","LGA_NAME","DISTRICT_NAME","TECTONIC_UNIT"]]
mindex_filtered_columns_df.head()
# Out:
#                           TITLE SUB_TYPE      STAGE  \
# 0                       Baneygo  Openpit  Operating
# 1  Beatons Creek - Golden Crown  Openpit  Operating
# 2          Big Bell Underground  Decline  Operating
# 3              Aladdin Open Pit  Openpit  Operating
# 4     Bluebird - Bluebird South  Openpit  Operating
#
#                   PROJECT_TITLE   LONGITUDE   LATITUDE        COMMODITIES  \
# 0     Duketon / Regis Resources  122.312500 -27.963344              Au Ag
# 1              Beatons Creek JV  120.101598 -21.870333  Au Ag As Cu Bi Sb
# 2  Cue Gold - Central Murchison  117.655357 -27.318659              Au Ag
# 3  Cue Gold - Central Murchison  118.347188 -26.869470              Au Ag
# 4  Cue Gold - Central Murchison  118.425102 -26.716249              Au Ag
#
#   COMMODITY_GROUP_NAME TARGET_GROUP_NAME                LGA_NAME  \
# 0       Precious metal              GOLD      LAVERTON, SHIRE OF
# 1       Precious metal              GOLD  EAST PILBARA, SHIRE OF
# 2       Precious metal              GOLD           CUE, SHIRE OF
# 3       Precious metal              GOLD   MEEKATHARRA, SHIRE OF
# 4       Precious metal              GOLD   MEEKATHARRA, SHIRE OF
#
#   DISTRICT_NAME                    TECTONIC_UNIT
# 0  MT. MARGARET  Eastern Goldfields Superterrane
# 1     NULLAGINE      Northeast Pilbara Sub-basin
# 2           CUE                  Youanmi Terrane
# 3   MEEKATHARRA                  Youanmi Terrane
# 4   MEEKATHARRA                  Youanmi Terrane

# %%
print(mindex_filtered_columns_df.shape)
print("------------------------------------------------------------------")
print(mindex_filtered_columns_df.columns)
print("------------------------------------------------------------------")
print(mindex_filtered_columns_df.dtypes)
# Out:
# (1329, 12)
# ------------------------------------------------------------------
# Index(['TITLE', 'SUB_TYPE', 'STAGE', 'PROJECT_TITLE', 'LONGITUDE', 'LATITUDE',
#        'COMMODITIES', 'COMMODITY_GROUP_NAME', 'TARGET_GROUP_NAME', 'LGA_NAME',
#        'DISTRICT_NAME', 'TECTONIC_UNIT'],
#       dtype='object')
# ------------------------------------------------------------------
# TITLE                    object
# SUB_TYPE                 object
# STAGE                    object
# PROJECT_TITLE            object
# LONGITUDE               float64
# LATITUDE                float64
# COMMODITIES              object
# COMMODITY_GROUP_NAME     object
# TARGET_GROUP_NAME        object
# LGA_NAME                 object
# DISTRICT_NAME            object
# TECTONIC_UNIT            object
# dtype: object

# %%
# Filter by relivant commodities
mindex_filtered_commodities_df = mindex_filtered_columns_df[(mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "GOLD") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "SILVER") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "COPPER - LEAD - ZINC") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "IRON ORE") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "COPPER") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "LEAD") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "ZINC") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "NICKEL") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "MANGANESE ORE") |
                            (mindex_filtered_columns_df["TARGET_GROUP_NAME"] == "TIN - TANTALUM - LITHIUM")

                            ]


print(mindex_filtered_commodities_df.nunique())
print(mindex_filtered_commodities_df.shape)
# Out:
# TITLE                   526
# SUB_TYPE                  6
# STAGE                     2
# PROJECT_TITLE           154
# LONGITUDE               522
# LATITUDE                523
# COMMODITIES              52
# COMMODITY_GROUP_NAME      5
# TARGET_GROUP_NAME         6
# LGA_NAME                 28
# DISTRICT_NAME            36
# TECTONIC_UNIT            33
# dtype: int64
# (526, 12)

# %% [markdown]
# ### Resources/Volume.csv ETL

# %%
# Make a reference to the solar_data_by_postcode.csv file path

estimates_csv_path = "Resources/Resource_Estimates_by_Project.csv"

# Import the solar_data_by_postcode.csv file as a DataFrame


minedex_vol_raw_df = pd.read_csv(estimates_csv_path, encoding="utf-8")



# Check the csv imported correctly
print(minedex_vol_raw_df.shape)
minedex_vol_raw_df.head()
# Out:
# (2319, 31)
#   PROJ_CODE      PROJ_NAME     PROJ_SHORT PRI_P_COM  LOC_SITE   LATITUDE  \
# 0    J05288     8 Mile Dam     8 Mile Dam      Gold  S0236141 -30.645301
# 1    J01022  Abednego West  Abednego West      Gold  S0002219 -28.833361
# 2    J00545  Abra - Mulgul  Abra - Mulgul      Lead  S0001538 -24.638213
# 3    J00545  Abra - Mulgul  Abra - Mulgul      Lead  S0001538 -24.638213
# 4    J03432         Abydos         Abydos      Iron  S0023261 -21.143820
#
#     LONGITUDE                        TECT_UNIT EST_COM EST_COM_AB  ...  \
# 0  121.462207  Eastern Goldfields Superterrane    Gold         Au  ...
# 1  121.773903  Eastern Goldfields Superterrane    Gold         Au  ...
# 2  118.585512                     Edmund Basin    Lead         Pb  ...
# 3  118.585512                     Edmund Basin  Silver         Ag  ...
# 4  119.105797                Gorge Creek Basin    Iron         Fe  ...
#
#     RV_QTY_G   RV_QTY_GU       RV_CON        RV_CON_U      ARV_CON  \
# 0        NaN         NaN          NaN             NaN          NaN
# 1        NaN         NaN          NaN             NaN          NaN
# 2   8.800000     percent     906.4000       kilotonne          NaN
# 3  24.000000  gram/tonne  247200.0000        kilogram  7947664.658
# 4  56.869231     percent       2.2179  million tonnes          NaN
#
#       ARV_CON_U     POINT_SIZE      POINT_UNIT  \
# 0           NaN    9763.969632        kilogram
# 1           NaN     147.000000        kilogram
# 2           NaN    3382.000000       kilotonne
# 3  ounce (troy)  797000.000000        kilogram
# 4           NaN      11.050400  million tonnes
#
#                                             PROJ_URL  EXTRACT_DA
# 0  https://minedex.dmirs.wa.gov.au/Web/projects/d...  19/10/2022
# 1  https://minedex.dmirs.wa.gov.au/Web/projects/d...  19/10/2022
# 2  https://minedex.dmirs.wa.gov.au/Web/projects/d...  19/10/2022
# 3  https://minedex.dmirs.wa.gov.au/Web/projects/d...  19/10/2022
# 4  https://minedex.dmirs.wa.gov.au/Web/projects/d...  19/10/2022
#
# [5 rows x 31 columns]

# %%
minedex_vol_raw_df.columns
# Out:
# Index(['PROJ_CODE', 'PROJ_NAME', 'PROJ_SHORT', 'PRI_P_COM', 'LOC_SITE',
#        'LATITUDE', 'LONGITUDE', 'TECT_UNIT', 'EST_COM', 'EST_COM_AB',
#        'EST_COM_P', 'RES_QTY', 'RES_QTY_U', 'RES_QTY_G', 'RES_QTY_GU',
#        'RES_CON', 'RES_CON_U', 'ARES_CON', 'ARES_CON_U', 'RV_QTY', 'RV_QTY_U',
#        'RV_QTY_G', 'RV_QTY_GU', 'RV_CON', 'RV_CON_U', 'ARV_CON', 'ARV_CON_U',
#        'POINT_SIZE', 'POINT_UNIT', 'PROJ_URL', 'EXTRACT_DA'],
#       dtype='object')

# %%
# Retaining rows that fit condition == yes in column 'EST_COM_P', meaning that the information retained is 
# from the main resource the mine aims to collect. 

minedex_vol_raw_df = minedex_vol_raw_df.loc[(minedex_vol_raw_df['EST_COM_P'] == 'Yes')]

# Selecting desired columns 
volume_mindex_filtered_columns_df = minedex_vol_raw_df[["PROJ_CODE","PROJ_NAME", "PRI_P_COM", 'RES_QTY', 'RES_QTY_U',
       'RES_CON', 'RES_CON_U', 'ARES_CON', 'ARES_CON_U']]

print(volume_mindex_filtered_columns_df.shape)
volume_mindex_filtered_columns_df.head()
# Out:
# (834, 9)
#   PROJ_CODE      PROJ_NAME PRI_P_COM     RES_QTY       RES_QTY_U      RES_CON  \
# 0    J05288     8 Mile Dam      Gold    7.014346  million tonnes  9763.969632
# 1    J01022  Abednego West      Gold    0.070000  million tonnes   147.000000
# 2    J00545  Abra - Mulgul      Lead   34.400000  million tonnes  2475.600000
# 4    J03432         Abydos      Iron   15.500000  million tonnes     8.832500
# 8    J00744    Admiral Bay      Zinc  170.000000  million tonnes  6970.000000
#
#         RES_CON_U       ARES_CON    ARES_CON_U
# 0        kilogram  313918.917400  ounce (troy)
# 1        kilogram    4726.159809  ounce (troy)
# 2       kilotonne            NaN           NaN
# 4  million tonnes            NaN           NaN
# 8       kilotonne            NaN           NaN

# %%
# Filter by relevant commodities
volume_filtered_commodities_df = volume_mindex_filtered_columns_df[(volume_mindex_filtered_columns_df["PRI_P_COM"] == "Gold") |
                            (volume_mindex_filtered_columns_df["PRI_P_COM"] == "Silver") |        
                            (volume_mindex_filtered_columns_df["PRI_P_COM"] == "Iron") |
                            (volume_mindex_filtered_columns_df["PRI_P_COM"] == "Copper") |
                            (volume_mindex_filtered_columns_df["PRI_P_COM"] == "Lead") |
                            (volume_mindex_filtered_columns_df["PRI_P_COM"] == "Zinc") |
                            (volume_mindex_filtered_columns_df["PRI_P_COM"] == "Nickel") |
                            (volume_mindex_filtered_columns_df["PRI_P_COM"] == "Manganese") |
                            (volume_mindex_filtered_columns_df["PRI_P_COM"] == "Lithium")
                            ]


print(volume_filtered_commodities_df.nunique())
print(volume_filtered_commodities_df.shape)
# Out:
# PROJ_CODE     627
# PROJ_NAME     627
# PRI_P_COM       8
# RES_QTY       577
# RES_QTY_U       1
# RES_CON       610
# RES_CON_U       3
# ARES_CON      359
# ARES_CON_U      1
# dtype: int64
# (627, 9)

# %%
volume_filtered_commodities_df.head()
# Out:
#   PROJ_CODE      PROJ_NAME PRI_P_COM     RES_QTY       RES_QTY_U      RES_CON  \
# 0    J05288     8 Mile Dam      Gold    7.014346  million tonnes  9763.969632
# 1    J01022  Abednego West      Gold    0.070000  million tonnes   147.000000
# 2    J00545  Abra - Mulgul      Lead   34.400000  million tonnes  2475.600000
# 4    J03432         Abydos      Iron   15.500000  million tonnes     8.832500
# 8    J00744    Admiral Bay      Zinc  170.000000  million tonnes  6970.000000
#
#         RES_CON_U       ARES_CON    ARES_CON_U
# 0        kilogram  313918.917400  ounce (troy)
# 1        kilogram    4726.159809  ounce (troy)
# 2       kilotonne            NaN           NaN
# 4  million tonnes            NaN           NaN
# 8       kilotonne            NaN           NaN

# %%
# check wether columns have unique measuring untis. 
print(volume_filtered_commodities_df.RES_QTY_U.unique())
print('------------------------------------------')
print(volume_filtered_commodities_df.RES_CON_U.unique())  # conversion will need to take place. 
print('------------------------------------------')
print(volume_filtered_commodities_df.ARES_CON_U.unique())
# Out:
# ['million tonnes' nan]
# ------------------------------------------
# ['kilogram' 'kilotonne' 'million tonnes' nan]
# ------------------------------------------
# ['ounce (troy)' nan]

# %%
# check rows with nan values in 'RES_QTY' column.
volume_filtered_commodities_df[volume_filtered_commodities_df['RES_QTY'].isna()]
# Out:
#      PROJ_CODE                                          PROJ_NAME PRI_P_COM  \
# 95      J01716                                              Badja      Gold
# 196     J03932  Brockman 2 - Nammuldi - Silvergrass - Homestea...      Iron
# 235     J01026                                 Bullfinch Tailings      Gold
# 363     J00481                                            Channar      Iron
# 444     J01557                        Cuddingwarra - Morning Star      Gold
# 1165    J03929                               Marandoo / Rio Tinto      Iron
# 1267    J01599                            Mountain Devil - Dulcie      Gold
# 1588    J03930                             Paraburdoo / Rio Tinto      Iron
# 1781    J01653                                            Ronstan      Gold
# 1989    J03928                              Tom Price / Rio Tinto      Iron
# 1997    J00691                            Turee Syncline Iron Ore      Iron
#
#       RES_QTY RES_QTY_U  RES_CON RES_CON_U  ARES_CON ARES_CON_U
# 95        NaN       NaN      NaN       NaN       NaN        NaN
# 196       NaN       NaN      NaN       NaN       NaN        NaN
# 235       NaN       NaN      NaN       NaN       NaN        NaN
# 363       NaN       NaN      NaN       NaN       NaN        NaN
# 444       NaN       NaN      NaN       NaN       NaN        NaN
# 1165      NaN       NaN      NaN       NaN       NaN        NaN
# 1267      NaN       NaN      NaN       NaN       NaN        NaN
# 1588      NaN       NaN      NaN       NaN       NaN        NaN
# 1781      NaN       NaN      NaN       NaN       NaN        NaN
# 1989      NaN       NaN      NaN       NaN       NaN        NaN
# 1997      NaN       NaN      NaN       NaN       NaN        NaN

# %%
# drop duplicates
volume_filtered_commodities_df.drop_duplicates(inplace = True)

# drop rows with nan values in 'RES_QTY' columns
volume_filtered_commodities_df.dropna(subset=['RES_QTY'], inplace= True)

volume_filtered_commodities_df
# Out:
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#      PROJ_CODE                              PROJ_NAME PRI_P_COM     RES_QTY  \
# 0       J05288                             8 Mile Dam      Gold    7.014346
# 1       J01022                          Abednego West      Gold    0.070000
# 2       J00545                          Abra - Mulgul      Lead   34.400000
# 4       J03432                                 Abydos      Iron   15.500000
# 8       J00744                            Admiral Bay      Zinc  170.000000
# ...        ...                                    ...       ...         ...
# 2313    J02775                 Yundamindera / Saracen      Gold    2.428000
# 2314    J00371                      Yundamindra / Nex      Gold    2.451000
# 2316    J04000                      Zanthus Magnetite      Iron  103.600000
# 2317    J01082                    Zelica - Eucalyptus      Gold    1.537800
# 2318    J03563  Zuleika North - Ora Banda / Evolution      Gold    5.770000
#
#            RES_QTY_U       RES_CON       RES_CON_U       ARES_CON  \
# 0     million tonnes   9763.969632        kilogram  313918.917400
# 1     million tonnes    147.000000        kilogram    4726.159809
# 2     million tonnes   2475.600000       kilotonne            NaN
# 4     million tonnes      8.832500  million tonnes            NaN
# 8     million tonnes   6970.000000       kilotonne            NaN
# ...              ...           ...             ...            ...
# 2313  million tonnes   3826.200000        kilogram  123015.188200
# 2314  million tonnes   4293.700000        kilogram  138045.662400
# 2316  million tonnes     27.454000  million tonnes            NaN
# 2317  million tonnes   3682.560000        kilogram  118397.054900
# 2318  million tonnes  11254.600000        kilogram  361843.797200
#
#         ARES_CON_U
# 0     ounce (troy)
# 1     ounce (troy)
# 2              NaN
# 4              NaN
# 8              NaN
# ...            ...
# 2313  ounce (troy)
# 2314  ounce (troy)
# 2316           NaN
# 2317  ounce (troy)
# 2318  ounce (troy)
#
# [616 rows x 9 columns]

# %%
# rename columns for better context
volume_filtered_commodities_df =  volume_filtered_commodities_df.rename(columns={'RES_QTY_U': 'TOT_MIN_RES_QUANTITY', 
                                    'ARES_CON':'RES_ALT_CONT_COM','RES_CON_U': 'TOT_MIN_RES_CONT_COM_UNIT', 'ARES_CON_U': 'TOT_MIN_RES_ALT_CONT_COM_UNIT'})

volume_filtered_commodities_df
# Out:
#      PROJ_CODE                              PROJ_NAME PRI_P_COM     RES_QTY  \
# 0       J05288                             8 Mile Dam      Gold    7.014346
# 1       J01022                          Abednego West      Gold    0.070000
# 2       J00545                          Abra - Mulgul      Lead   34.400000
# 4       J03432                                 Abydos      Iron   15.500000
# 8       J00744                            Admiral Bay      Zinc  170.000000
# ...        ...                                    ...       ...         ...
# 2313    J02775                 Yundamindera / Saracen      Gold    2.428000
# 2314    J00371                      Yundamindra / Nex      Gold    2.451000
# 2316    J04000                      Zanthus Magnetite      Iron  103.600000
# 2317    J01082                    Zelica - Eucalyptus      Gold    1.537800
# 2318    J03563  Zuleika North - Ora Banda / Evolution      Gold    5.770000
#
#      TOT_MIN_RES_QUANTITY       RES_CON TOT_MIN_RES_CONT_COM_UNIT  \
# 0          million tonnes   9763.969632                  kilogram
# 1          million tonnes    147.000000                  kilogram
# 2          million tonnes   2475.600000                 kilotonne
# 4          million tonnes      8.832500            million tonnes
# 8          million tonnes   6970.000000                 kilotonne
# ...                   ...           ...                       ...
# 2313       million tonnes   3826.200000                  kilogram
# 2314       million tonnes   4293.700000                  kilogram
# 2316       million tonnes     27.454000            million tonnes
# 2317       million tonnes   3682.560000                  kilogram
# 2318       million tonnes  11254.600000                  kilogram
#
#       RES_ALT_CONT_COM TOT_MIN_RES_ALT_CONT_COM_UNIT
# 0        313918.917400                  ounce (troy)
# 1          4726.159809                  ounce (troy)
# 2                  NaN                           NaN
# 4                  NaN                           NaN
# 8                  NaN                           NaN
# ...                ...                           ...
# 2313     123015.188200                  ounce (troy)
# 2314     138045.662400                  ounce (troy)
# 2316               NaN                           NaN
# 2317     118397.054900                  ounce (troy)
# 2318     361843.797200                  ounce (troy)
#
# [616 rows x 9 columns]

# %%
if volume_filtered_commodities_df['TOT_MIN_RES_CONT_COM_UNIT'].str == 'kilogram':
    volume_filtered_commodities_df['RES_CON'] = volume_filtered_commodities_df['RES_CON']*0.0000001
elif volume_filtered_commodities_df['TOT_MIN_RES_CONT_COM_UNIT'].str == 'million tonnes': 
    volume_filtered_commodities_df['RES_CON'] = volume_filtered_commodities_df['RES_CON']*1000
    

volume_filtered_commodities_df['TOT_MIN_RES_CONT_COM_UNIT'] = volume_filtered_commodities_df['TOT_MIN_RES_CONT_COM_UNIT'].str.replace("kilogram","kilotonne")
volume_filtered_commodities_df['TOT_MIN_RES_CONT_COM_UNIT'] = volume_filtered_commodities_df['TOT_MIN_RES_CONT_COM_UNIT'].str.replace("million tonnes","kilotonne")

volume_filtered_commodities_df
# Out:
#      PROJ_CODE                              PROJ_NAME PRI_P_COM     RES_QTY  \
# 0       J05288                             8 Mile Dam      Gold    7.014346
# 1       J01022                          Abednego West      Gold    0.070000
# 2       J00545                          Abra - Mulgul      Lead   34.400000
# 4       J03432                                 Abydos      Iron   15.500000
# 8       J00744                            Admiral Bay      Zinc  170.000000
# ...        ...                                    ...       ...         ...
# 2313    J02775                 Yundamindera / Saracen      Gold    2.428000
# 2314    J00371                      Yundamindra / Nex      Gold    2.451000
# 2316    J04000                      Zanthus Magnetite      Iron  103.600000
# 2317    J01082                    Zelica - Eucalyptus      Gold    1.537800
# 2318    J03563  Zuleika North - Ora Banda / Evolution      Gold    5.770000
#
#      TOT_MIN_RES_QUANTITY       RES_CON TOT_MIN_RES_CONT_COM_UNIT  \
# 0          million tonnes   9763.969632                 kilotonne
# 1          million tonnes    147.000000                 kilotonne
# 2          million tonnes   2475.600000                 kilotonne
# 4          million tonnes      8.832500                 kilotonne
# 8          million tonnes   6970.000000                 kilotonne
# ...                   ...           ...                       ...
# 2313       million tonnes   3826.200000                 kilotonne
# 2314       million tonnes   4293.700000                 kilotonne
# 2316       million tonnes     27.454000                 kilotonne
# 2317       million tonnes   3682.560000                 kilotonne
# 2318       million tonnes  11254.600000                 kilotonne
#
#       RES_ALT_CONT_COM TOT_MIN_RES_ALT_CONT_COM_UNIT
# 0        313918.917400                  ounce (troy)
# 1          4726.159809                  ounce (troy)
# 2                  NaN                           NaN
# 4                  NaN                           NaN
# 8                  NaN                           NaN
# ...                ...                           ...
# 2313     123015.188200                  ounce (troy)
# 2314     138045.662400                  ounce (troy)
# 2316               NaN                           NaN
# 2317     118397.054900                  ounce (troy)
# 2318     361843.797200                  ounce (troy)
#
# [616 rows x 9 columns]

# %%
# Push cleaned DataFrame to a new CSV file
mindex_filtered_commodities_df.to_csv("Output/Operating_Mines_Cleaned.csv",
                  encoding="utf-8", index=False, header=True)

volume_filtered_commodities_df.to_csv("Output/Volume_Operating_Mines_Cleaned.csv",
                  encoding="utf-8", index=False, header=True)

# %%
# Push to the postgres DB
# import config_dm
import config_js


protocol = 'postgresql'
username = 'postgres'
# password = config_dm.postgres_key
password = config_js.postgres_key
host = 'localhost'
port = 5432
database_name = 'project3_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
insp = inspect(engine)

# %%
# Inspect the DB tables
insp.get_table_names()
# Out:
# ['mindex_filtered_commodities_df', 'volume_mindex_filtered_commodities_df']

# %%
# Push the dataframe to the DB
mindex_filtered_commodities_df.to_sql(name='mindex_filtered_commodities_df', con=engine, if_exists='append', index=False)

volume_filtered_commodities_df.to_sql(name='volume_mindex_filtered_commodities_df', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UniqueViolation: duplicate key value violates unique constraint "volume_mindex_filtered_commodities_df_pkey"
# DETAIL:  Key ("PROJ_CODE")=(J05288) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1764\3029956462.py in <module>
#       2 mindex_filtered_commodities_df.to_sql(name='mindex_filtered_commodities_df', con=engine, if_exists='append', index=False)
#       3
# ----> 4 volume_filtered_commodities_df.to_sql(name='volume_mindex_filtered_commodities_df', con=engine, if_exists='append', index=False)
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1018             )
#    1019         else:
# -> 1020             return meth(self, multiparams, params)
#    1021
#    1022     def _execute_function(self, func, multiparams, params):
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1137             distilled_params,
#    1138             compiled_sql,
# -> 1139             distilled_params,
#    1140         )
#    1141         if self._has_events or self.engine._has_events:
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1322         except BaseException as e:
#    1323             self._handle_dbapi_exception(
# -> 1324                 e, statement, parameters, cursor, context
#    1325             )
#    1326
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1516             elif should_wrap:
#    1517                 util.raise_(
# -> 1518                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1519                 )
#    1520             else:
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1262                 if not evt_handled:
#    1263                     self.dialect.do_executemany(
# -> 1264                         cursor, statement, parameters, context
#    1265                     )
#    1266             elif not parameters and context.no_parameters:
#
# c:\Users\jess9\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "volume_mindex_filtered_commodities_df_pkey"
# DETAIL:  Key ("PROJ_CODE")=(J05288) already exists.
#
# [SQL: INSERT INTO volume_mindex_filtered_commodities_df ("PROJ_CODE", "PROJ_NAME", "PRI_P_COM", "RES_QTY", "TOT_MIN_RES_QUANTITY", "RES_CON", "TOT_MIN_RES_CONT_COM_UNIT", "RES_ALT_CONT_COM", "TOT_MIN_RES_ALT_CONT_COM_UNIT") VALUES (%(PROJ_CODE)s, %(PROJ_NAME)s, %(PRI_P_COM)s, %(RES_QTY)s, %(TOT_MIN_RES_QUANTITY)s, %(RES_CON)s, %(TOT_MIN_RES_CONT_COM_UNIT)s, %(RES_ALT_CONT_COM)s, %(TOT_MIN_RES_ALT_CONT_COM_UNIT)s)]
# [parameters: ({'PROJ_CODE': 'J05288', 'PROJ_NAME': '8 Mile Dam', 'PRI_P_COM': 'Gold', 'RES_QTY': 7.014346000000001, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 9763.969631999998, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': 313918.9174, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': 'ounce (troy)'}, {'PROJ_CODE': 'J01022', 'PROJ_NAME': 'Abednego West', 'PRI_P_COM': 'Gold', 'RES_QTY': 0.07, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 147.0, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': 4726.159809000001, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': 'ounce (troy)'}, {'PROJ_CODE': 'J00545', 'PROJ_NAME': 'Abra - Mulgul', 'PRI_P_COM': 'Lead', 'RES_QTY': 34.4, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 2475.6, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': None, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': None}, {'PROJ_CODE': 'J03432', 'PROJ_NAME': 'Abydos', 'PRI_P_COM': 'Iron', 'RES_QTY': 15.5, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 8.8325, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': None, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': None}, {'PROJ_CODE': 'J00744', 'PROJ_NAME': 'Admiral Bay', 'PRI_P_COM': 'Zinc', 'RES_QTY': 170.0, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 6970.0, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': None, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': None}, {'PROJ_CODE': 'J00098', 'PROJ_NAME': 'Agnew - Emu', 'PRI_P_COM': 'Gold', 'RES_QTY': 19.879, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 106195.46, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': 3414263.367, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': 'ounce (troy)'}, {'PROJ_CODE': 'J01130', 'PROJ_NAME': 'Ajana', 'PRI_P_COM': 'Lead', 'RES_QTY': 0.394419, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 25.415222, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': None, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': None}, {'PROJ_CODE': 'J00002', 'PROJ_NAME': 'Albury Heath', 'PRI_P_COM': 'Gold', 'RES_QTY': 0.528, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 1103.52, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': 35478.99233, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': 'ounce (troy)'}  ... displaying 10 of 616 total bound parameter sets ...  {'PROJ_CODE': 'J01082', 'PROJ_NAME': 'Zelica - Eucalyptus', 'PRI_P_COM': 'Gold', 'RES_QTY': 1.5378, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 3682.56, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': 118397.0549, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': 'ounce (troy)'}, {'PROJ_CODE': 'J03563', 'PROJ_NAME': 'Zuleika North - Ora Banda / Evolution', 'PRI_P_COM': 'Gold', 'RES_QTY': 5.77, 'TOT_MIN_RES_QUANTITY': 'million tonnes', 'RES_CON': 11254.6, 'TOT_MIN_RES_CONT_COM_UNIT': 'kilotonne', 'RES_ALT_CONT_COM': 361843.7972, 'TOT_MIN_RES_ALT_CONT_COM_UNIT': 'ounce (troy)'})]
# (Background on this error at: http://sqlalche.me/e/gkpj)
